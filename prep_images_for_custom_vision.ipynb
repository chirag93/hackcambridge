# %%
import cv2
import argparse
import os
import numpy as np

import matplotlib.pyplot as plt

# %%
#!/usr/local/bin/python3


# # Construct the argument parser and parse the arguments
# ap = argparse.ArgumentParser()
# ap.add_argument("-ext", "--extension", required=False, default='png', help="extension name. default is 'png'.")
# ap.add_argument("-o", "--output", required=False, default='output.mp4', help="output video file")
# args = vars(ap.parse_args())

# Arguments
dir_path = 'images/id014_rb_nez2_npz1_38/'
ext = 'png'
output = 'output.mp4'

images = []
for f in os.listdir(dir_path):
    if f.endswith(ext):
        images.append(f)

# Determine the width and height from the first image
image_path = os.path.join(dir_path, images[0])
frame = cv2.imread(image_path)
# cv2.imshow('video',frame)
height, width, channels = frame.shape

# Define the codec and create VideoWriter object
fourcc = cv2.VideoWriter_fourcc(*'mp4v') # Be sure to use lower case
out = cv2.VideoWriter(output, fourcc, 20.0, (width, height))

for image in images:

    image_path = os.path.join(dir_path, image)
    frame = cv2.imread(image_path)

    out.write(frame) # Write out frame to video

#     cv2.imshow('video',frame)
#     if (cv2.waitKey(1) & 0xFF) == ord('q'): # Hit `q` to exit
#         break

# Release everything if job is finished
out.release()
cv2.destroyAllWindows()

print("The output video is {}".format(output))

# %%
c = 0

for f in os.listdir('images'):
    print(f)
    
    if c == 0:
        c+=1
        continue
    
    filename = f.replace('.npz.npy','')
    
    new_folder = f.replace('.npz.npy','')
    os.chdir('images')
    
    try:
        os.mkdir(new_folder)
    except:
        pass

    os.chdir('..')
    
    image_array = np.load(os.path.join('images',f))
    label_array = np.load(os.path.join('labels',f))
    
    break
    
    print(np.sum(label_array))
    
    vmin1 = np.min(image_array[:][0])
    vmax1 = np.max(image_array[:][0])
    
    vmin2 = np.min(image_array[:][1])
    vmax2 = np.max(image_array[:][1])
    
    vmin3 = np.min(image_array[:][2])
    vmax3 = np.max(image_array[:][2])
    
    vmin4 = np.min(image_array[:][3])
    vmax4 = np.max(image_array[:][3])
    
    
    # Load file with 
    for i in range(image_array.shape[0]):
        
        plt.figure(figsize=(10,10))
        
        if label_array[i] == 1:
            plt.suptitle('Seizure happening',fontsize=20)
        else:
            plt.suptitle('No seizure',fontsize=20)
        
        plt.subplot(2,2,1)
        plt.title('Low')
        plt.imshow(image_array[i][0],vmin=vmin1, vmax=vmax1)
        
        plt.subplot(2,2,2)
        plt.title('Theta')
        plt.imshow(image_array[i][1],vmin=vmin2, vmax=vmax2)
        
        plt.subplot(2,2,3)
        plt.title('Gamma')
        plt.imshow(image_array[i][2],vmin=vmin3, vmax=vmax3)
        
        plt.subplot(2,2,4)
        plt.title('High')
        plt.imshow(image_array[i][3],vmin=vmin4, vmax=vmax4)
        
        plt.savefig('images/'+new_folder+'/'+str(i)+'.png')

    # Generate the plots & save to file
    
    break

# %%
c = 0

for f in os.listdir('images'):
    print(f)
    
    if c==0:
        c+=1
        continue

    
    filename = f.replace('.npz.npy','')
    
    new_folder = f.replace('.npz.npy','')
    os.chdir('images')
    
    try:
        os.mkdir(new_folder)
    except:
        pass

    os.chdir('..')
    
    image_array = np.load(os.path.join('images',f))
    label_array = np.load(os.path.join('labels',f))
    
    print(np.sum(label_array))
    
    vmin2 = np.min(image_array[:][1])
    vmax2 = np.max(image_array[:][1])
    
    # Load file with 
    for i in range(image_array.shape[0]):
        
        plt.figure()
        
#         if label_array[i] == 1:
#             pass
# #             plt.suptitle('Seizure happening',fontsize=20)
#         else:
#             pass
# #             plt.suptitle('No seizure',fontsize=20)
        plt.axis('off')
#         plt.title('Theta')
        plt.imshow(image_array[i][1],vmin=vmin2, vmax=vmax2)
        
        if label_array[i] == 1:
            plt.savefig('images/'+new_folder+'/abc'+str(i)+'.png',bbox_inches='tight',pad_inches=0)
        else:
            plt.savefig('images/'+new_folder+'/'+str(i)+'.png',bbox_inches='tight',pad_inches=0)
            
    # Generate the plots & save to file
    
    break
# Out:
# id002_cj_nez1_npz1_10.npz.npy
# id014_rb_nez2_npz1_38.npz.npy
# 243.0
# /usr/local/lib/python3.6/site-packages/matplotlib/pyplot.py:528: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   max_open_warning, RuntimeWarning)

# %%
np.sum(label_array)

# %%
image_array.shape

label_array.shape

# %%
np.sum(label_array)
print(f)

# %%
os.chdir('..')

# %%
os.listdir()

# %%
x.shape

# %%
y.shape

# %%
for g in os.listdir('labels'):

    
    break

# %%
# os.listdir()
os.mkdir('test')

# %%
os.mkdir('test/test')

# %%
os.chdir('Desktop')

# %%
os.listdir()

# %%
plt.axis('off')
